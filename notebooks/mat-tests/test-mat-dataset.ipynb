# %% [markdown]
# #### TEST TO OPEN .MAT FILES

# %%
from pathlib import Path
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
mat_path = Path("/Users/abirbou/code/afallo/brain_tumor_detection_project/notebooks/444.mat")

print(mat_path)
print(mat_path.exists())  # doit afficher True

with h5py.File(mat_path, "r") as f:
    grp = f["cjdata"]
    print(list(grp.keys()))   # par ex. ['image', 'label', 'PID']
    img = grp["image"][:]
    label = grp["label"][:]
    pid = grp["PID"][:]
    tumor_border = grp["tumorBorder"][:]
    tumor_mask = grp["tumorMask"][:]


print(img.shape)
print(label[0])
print(pid)

plt.imshow(img, cmap="gray")
# Out:
# /Users/abirbou/code/afallo/brain_tumor_detection_project/notebooks/444.mat
# False
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       3 print(mat_path)
#       4 print(mat_path.exists())  # doit afficher True
# ----> 6 with h5py.File(mat_path, "r") as f:
#       7     grp = f["cjdata"]
#       8     print(list(grp.keys()))   # par ex. ['image', 'label', 'PID']
#
# File ~/.pyenv/versions/3.10.6/envs/brain_tumor_detection_project/lib/python3.10/site-packages/h5py/_hl/files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
# ...

# %%
plt.imshow(tumor_mask, cmap="gray")

# %%
plt.imshow(tumor_border, cmap="gray")
